# %%
import requests
import json
import os
import time
import re
from urllib.parse import urljoin
import math

# NEW: Configuration flags for easy switching of download components
DOWNLOAD_MANIFEST = True
DOWNLOAD_METADATA = True
DOWNLOAD_IMAGES = False

# %%
def sanitize_filename(filename):
    return re.sub(r'[<>:"/\\|?*]', '', filename).strip()

def extract_metadata(manifest_data):
    metadata = {}
    if 'metadata' in manifest_data:
        for item in manifest_data['metadata']:
            key = item.get('label', '')
            value = item.get('value', '')
            metadata[key] = value
    return metadata

# UPDATED: Modified to respect configuration flags
def download_manifest(manifest_url, json_folder, title):
    if not DOWNLOAD_MANIFEST and not DOWNLOAD_METADATA:
        print("Manifest and metadata download are disabled.")
        return None

    try:
        response = requests.get(manifest_url)
        response.raise_for_status()
        manifest_data = response.json()
        
        if DOWNLOAD_MANIFEST:
            sanitized_title = sanitize_filename(title)
            manifest_filename = f"{sanitized_title[:100]}_manifest.json"
            manifest_filepath = os.path.join(json_folder, manifest_filename)
            with open(manifest_filepath, 'w', encoding='utf-8') as f:
                json.dump(manifest_data, f, indent=2)
            print(f"Downloaded manifest: {manifest_filepath}")
        
        if DOWNLOAD_METADATA:
            metadata = extract_metadata(manifest_data)
            metadata_filename = f"{sanitized_title[:100]}_metadata.json"
            metadata_filepath = os.path.join(json_folder, metadata_filename)
            with open(metadata_filepath, 'w', encoding='utf-8') as f:
                json.dump(metadata, f, indent=2)
            print(f"Saved metadata: {metadata_filepath}")
        
        return manifest_data
    except requests.RequestException as e:
        print(f"Error processing manifest {manifest_url}: {e}")
        return None

# %%
def download_file(url, filepath):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()
        with open(filepath, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        return True
    except requests.RequestException as e:
        print(f"Error downloading file {url}: {e}")
        return False

def extract_image_urls(manifest_data):
    image_urls = []
    if 'sequences' in manifest_data:
        for sequence in manifest_data['sequences']:
            if 'canvases' in sequence:
                for canvas in sequence['canvases']:
                    if 'images' in canvas:
                        for image in canvas['images']:
                            if 'resource' in image and 'service' in image['resource']:
                                service = image['resource']['service']
                                if '@id' in service:
                                    base_url = service['@id']
                                    image_url = f"{base_url}/full/max/0/default.jpg"
                                    image_urls.append(image_url)
    return image_urls    
# UPDATED: Modified to respect configuration flag
def download_images(manifest_data, image_folder):
    if not DOWNLOAD_IMAGES:
        print("Image download is disabled.")
        return

    image_urls = extract_image_urls(manifest_data)
    for i, image_url in enumerate(image_urls):
        image_filename = f"image_{i+1}.jpg"
        image_filepath = os.path.join(image_folder, image_filename)
        if download_file(image_url, image_filepath):
            print(f"Downloaded image: {image_filepath}")
        else:
            print(f"Failed to download image: {image_url}")

# %%
def get_total_objects(api_url):
    try:
        response = requests.get(api_url)
        response.raise_for_status()
        data = response.json()
        return data.get('info', {}).get('record_count', 0)
    except requests.RequestException as e:
        print(f"Error fetching total object count: {e}")
        return 0
    
def get_page_size(api_url): #AMIR
    try:
        response = requests.get(api_url)
        response.raise_for_status()
        data = response.json()
        return data.get('info', {}).get('page_size', 0)
    except requests.RequestException as e:
        print(f"Error fetching page size: {e}")
        return 0

# %%
# UPDATED: Modified to use new folder structure and respect configuration flags
def process_objects(api_url, output_dir, total_objects, page_size):
    objects_processed = 0
    manifests_downloaded = 0
    page = 1
    total_pages = math.ceil(total_objects / page_size) #AMIR   # Assuming page_size is 50
    
    while api_url:
        try:
            print(f"Processing page {page} of {total_pages}")
            response = requests.get(api_url)
            response.raise_for_status()
            data = response.json()
            
            if 'records' not in data: #AMIR is record a standard key? if not we need to have a list of keys meaning record
                print(f"Unexpected API response structure: {json.dumps(data, indent=2)}")
                return manifests_downloaded

            records = data['records']
            print(f"Found {len(records)} objects on this page")
            print(f" records size {len(records)}")
            
            for record in records:
                objects_processed += 1
                system_number = record.get('systemNumber', 'Unknown') #AMIR  what if multiple objects have no system Number?
                                                                    #is systemNumber an standard key? if not ...
                title = record.get('_primaryTitle', 'Untitled')
                print(f"\nProcessing object {objects_processed} of {total_objects}: {system_number}")
                print(f"Title: {title}")
                
                manifest_url = record.get('_images', {}).get('_iiif_presentation_url')
                
                if manifest_url:
                    print(f"IIIF Manifest URL: {manifest_url}")
                    
                    # NEW: Create folders for this object
                    object_folder = os.path.join(output_dir, system_number)
                    json_folder = os.path.join(object_folder, f"{system_number}-json")
                    image_folder = os.path.join(object_folder, f"{system_number}-Image")
                    
                    if DOWNLOAD_MANIFEST or DOWNLOAD_METADATA:
                        os.makedirs(json_folder, exist_ok=True)
                    if DOWNLOAD_IMAGES:
                        os.makedirs(image_folder, exist_ok=True)
                    
                    manifest_data = download_manifest(manifest_url, json_folder, title)
                    if manifest_data:
                        if DOWNLOAD_IMAGES:
                            download_images(manifest_data, image_folder)
                        manifests_downloaded += 1
                else:
                    print("No IIIF manifest available for this object")
                
                time.sleep(1)  # Be nice to the server
            
            api_url = data.get('info', {}).get('next')
            print(f"test {api_url}")
            page += 1
            
        except requests.RequestException as e:
            print(f"Error processing objects page {api_url}: {e}")
            break
    
    return manifests_downloaded

# %%
# UPDATED: Added user prompt and configuration display
def main():
    base_api_url = "https://api.vam.ac.uk/v2/objects/search?q=iran&images=1&page_size=50&iiif=true"
    output_dir = r"C:\Users\mazou\Sarvistan\Victoria_Albert_v2"
    
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    total_objects = get_total_objects(base_api_url)
    page_size = get_page_size(base_api_url) #AMIR
    print(f"Total number of Iran-related objects with images: {total_objects}")
    print(f"page size: {page_size}") #AMIR
    print(f"Download configuration:")
    print(f"  Manifests: {'Enabled' if DOWNLOAD_MANIFEST else 'Disabled'}")
    print(f"  Metadata: {'Enabled' if DOWNLOAD_METADATA else 'Disabled'}")
    print(f"  Images: {'Enabled' if DOWNLOAD_IMAGES else 'Disabled'}")
    
    # NEW: Ask user if they want to continue
    user_input = input("Do you want to continue with the download? (yes/no): ").lower()
    if user_input != 'yes' and user_input != 'y':
        print("Download cancelled by user.")
        return
    
    if total_objects > 0:
        total_downloaded = process_objects(base_api_url, output_dir, 60, page_size ) #total_objects, page_size)
        print(f"\nFinished processing objects.")
        print(f"Downloaded {total_downloaded} IIIF manifests and their associated data from Victoria and Albert Museum.")
    else:
        print("No objects found matching the criteria.")

if __name__ == "__main__":
    main()
# Out:
# Total number of Iran-related objects with images: 5666
# page size: 50
# Download configuration:
#   Manifests: Enabled
#   Metadata: Enabled
#   Images: Disabled
# Do you want to continue with the download? (yes/no): y
# Processing page 1 of 2
# Found 50 objects on this page
#  records size 50
#
# Processing object 1 of 60: O405551
# Title: Shah Isma'il of Iran
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O405551/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O405551\O405551-json\Shah Isma'il of Iran_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O405551\O405551-json\Shah Isma'il of Iran_metadata.json
#
# Processing object 2 of 60: O1304867
# Title: Iran, Untitled
# No IIIF manifest available for this object
#
# Processing object 3 of 60: O1304870
# Title: Iran, Untitled
# No IIIF manifest available for this object
#
# Processing object 4 of 60: O1304869
# Title: Iran, Untitled
# No IIIF manifest available for this object
#
# Processing object 5 of 60: O1304868
# Title: Iran, Untitled
# No IIIF manifest available for this object
#
# Processing object 6 of 60: O1304866
# Title: Iran, Untitled
# No IIIF manifest available for this object
#
# Processing object 7 of 60: O1304865
# Title: Iran, Untitled
# No IIIF manifest available for this object
#
# Processing object 8 of 60: O1304871
# Title: Iran, Untitled
# No IIIF manifest available for this object
#
# Processing object 9 of 60: O1304872
# Title: Iran, Untitled
# No IIIF manifest available for this object
#
# Processing object 10 of 60: O405633
# Title: Shah Tahmasp of Iran
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O405633/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O405633\O405633-json\Shah Tahmasp of Iran_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O405633\O405633-json\Shah Tahmasp of Iran_metadata.json
#
# Processing object 11 of 60: O142438
# Title: Kermanshah, Iran
# No IIIF manifest available for this object
#
# Processing object 12 of 60: O111804
# Title:
# No IIIF manifest available for this object
#
# Processing object 13 of 60: O108133
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O108133/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O108133\O108133-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O108133\O108133-json\_metadata.json
#
# Processing object 14 of 60: O109559
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O109559/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O109559\O109559-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O109559\O109559-json\_metadata.json
#
# Processing object 15 of 60: O1242907
# Title: C.R. Smith Archive
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1242907/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1242907\O1242907-json\C.R. Smith Archive_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1242907\O1242907-json\C.R. Smith Archive_metadata.json
#
# Processing object 16 of 60: O1159909
# Title: Qajar
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1159909/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159909\O1159909-json\Qajar_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159909\O1159909-json\Qajar_metadata.json
#
# Processing object 17 of 60: O1159907
# Title: Qajar
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1159907/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159907\O1159907-json\Qajar_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159907\O1159907-json\Qajar_metadata.json
#
# Processing object 18 of 60: O1159899
# Title: Qajar
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1159899/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159899\O1159899-json\Qajar_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159899\O1159899-json\Qajar_metadata.json
#
# Processing object 19 of 60: O1160262
# Title: Qajar
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1160262/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1160262\O1160262-json\Qajar_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1160262\O1160262-json\Qajar_metadata.json
#
# Processing object 20 of 60: O1159911
# Title: Qajar
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1159911/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159911\O1159911-json\Qajar_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159911\O1159911-json\Qajar_metadata.json
#
# Processing object 21 of 60: O1159814
# Title: Qajar
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1159814/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159814\O1159814-json\Qajar_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159814\O1159814-json\Qajar_metadata.json
#
# Processing object 22 of 60: O282426
# Title: Tiles from a courtyard floor in Iran
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O282426/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O282426\O282426-json\Tiles from a courtyard floor in Iran_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O282426\O282426-json\Tiles from a courtyard floor in Iran_metadata.json
#
# Processing object 23 of 60: O1274487
# Title: Great Sand Desert, Iran, Journey 4
# No IIIF manifest available for this object
#
# Processing object 24 of 60: O33615
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O33615/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O33615\O33615-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O33615\O33615-json\_metadata.json
#
# Processing object 25 of 60: O67418
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O67418/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O67418\O67418-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O67418\O67418-json\_metadata.json
#
# Processing object 26 of 60: O54307
# Title: The Ardabil Carpet
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O54307/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O54307\O54307-json\The Ardabil Carpet_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O54307\O54307-json\The Ardabil Carpet_metadata.json
#
# Processing object 27 of 60: O1159913
# Title: Mothers of Martyrs
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1159913/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159913\O1159913-json\Mothers of Martyrs_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159913\O1159913-json\Mothers of Martyrs_metadata.json
#
# Processing object 28 of 60: O1159912
# Title: Mothers of Martyrs
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1159912/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159912\O1159912-json\Mothers of Martyrs_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1159912\O1159912-json\Mothers of Martyrs_metadata.json
#
# Processing object 29 of 60: O1744395
# Title: Untitled from the Az Div o Dad series
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1744395/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1744395\O1744395-json\Untitled from the Az Div o Dad series_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1744395\O1744395-json\Untitled from the Az Div o Dad series_metadata.json
#
# Processing object 30 of 60: O1772198
# Title: Untitled from the Az Div o Dad series
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1772198/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772198\O1772198-json\Untitled from the Az Div o Dad series_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772198\O1772198-json\Untitled from the Az Div o Dad series_metadata.json
# Processing object 31 of 60: O1772197
# Title: Untitled from the Az Div o Dad series
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1772197/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772197\O1772197-json\Untitled from the Az Div o Dad series_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772197\O1772197-json\Untitled from the Az Div o Dad series_metadata.json
#
# Processing object 32 of 60: O1772196
# Title: Untitled from the Az Div o Dad series
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1772196/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772196\O1772196-json\Untitled from the Az Div o Dad series_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772196\O1772196-json\Untitled from the Az Div o Dad series_metadata.json
#
# Processing object 33 of 60: O1772195
# Title: Untitled from the Az Div o Dad series
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1772195/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772195\O1772195-json\Untitled from the Az Div o Dad series_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772195\O1772195-json\Untitled from the Az Div o Dad series_metadata.json
#
# Processing object 34 of 60: O1772194
# Title: Untitled from the Az Div o Dad series
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1772194/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772194\O1772194-json\Untitled from the Az Div o Dad series_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772194\O1772194-json\Untitled from the Az Div o Dad series_metadata.json
#
# Processing object 35 of 60: O1772193
# Title: Untitled from the Az Div o Dad series
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1772193/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772193\O1772193-json\Untitled from the Az Div o Dad series_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1772193\O1772193-json\Untitled from the Az Div o Dad series_metadata.json
#
# Processing object 36 of 60: O1754795
# Title: Untitled from the Az Div o Dad series
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1754795/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1754795\O1754795-json\Untitled from the Az Div o Dad series_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1754795\O1754795-json\Untitled from the Az Div o Dad series_metadata.json
#
# Processing object 37 of 60: O123325
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O123325/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O123325\O123325-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O123325\O123325-json\_metadata.json
#
# Processing object 38 of 60: O97147
# Title: Portrait of Fath 'Ali Shah
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O97147/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O97147\O97147-json\Portrait of Fath 'Ali Shah_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O97147\O97147-json\Portrait of Fath 'Ali Shah_metadata.json
#
# Processing object 39 of 60: O143967
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O143967/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O143967\O143967-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O143967\O143967-json\_metadata.json
#
# Processing object 40 of 60: O85120
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O85120/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O85120\O85120-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O85120\O85120-json\_metadata.json
#
# Processing object 41 of 60: O86482
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O86482/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O86482\O86482-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O86482\O86482-json\_metadata.json
#
# Processing object 42 of 60: O11490
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O11490/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O11490\O11490-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O11490\O11490-json\_metadata.json
#
# Processing object 43 of 60: O211362
# Title: Tiles from a courtyard floor in Iran
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O211362/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O211362\O211362-json\Tiles from a courtyard floor in Iran_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O211362\O211362-json\Tiles from a courtyard floor in Iran_metadata.json
#
# Processing object 44 of 60: O211366
# Title: Tiles from a courtyard floor in Iran
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O211366/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O211366\O211366-json\Tiles from a courtyard floor in Iran_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O211366\O211366-json\Tiles from a courtyard floor in Iran_metadata.json
#
# Processing object 45 of 60: O211368
# Title: Tiles from a courtyard floor in Iran
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O211368/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O211368\O211368-json\Tiles from a courtyard floor in Iran_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O211368\O211368-json\Tiles from a courtyard floor in Iran_metadata.json
#
# Processing object 46 of 60: O211369
# Title: Tiles from a courtyard floor in Iran
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O211369/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O211369\O211369-json\Tiles from a courtyard floor in Iran_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O211369\O211369-json\Tiles from a courtyard floor in Iran_metadata.json
#
# Processing object 47 of 60: O282869
# Title: Roses from Qajar Iran
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O282869/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O282869\O282869-json\Roses from Qajar Iran_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O282869\O282869-json\Roses from Qajar Iran_metadata.json
#
# Processing object 48 of 60: O166798
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O166798/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O166798\O166798-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O166798\O166798-json\_metadata.json
#
# Processing object 49 of 60: O199491
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O199491/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O199491\O199491-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O199491\O199491-json\_metadata.json
#
# Processing object 50 of 60: O1954
# Title:
# IIIF Manifest URL: https://iiif.vam.ac.uk/collections/O1954/manifest.json
# Downloaded manifest: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1954\O1954-json\_manifest.json
# Saved metadata: C:\Users\mazou\Sarvistan\Victoria_Albert_v2\O1954\O1954-json\_metadata.json
# test None
#
# Finished processing objects.
# Downloaded 39 IIIF manifests and their associated data from Victoria and Albert Museum.
